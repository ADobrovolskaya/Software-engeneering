# %% [markdown]
# <a href="https://colab.research.google.com/github/ADobrovolskaya/Software-engeneering/blob/main/Translation_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

document = pipeline('translation_ru_to_it', model="Helsinki-NLP/opus-mt-tc-big-zle-it")

translation = document('Меня зовут не так как я хочу')

translation
# Out:
# config.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/478M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/336 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/991k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/817k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.43M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# [{'translation_text': "Il mio nome non e' quello che voglio."}]
